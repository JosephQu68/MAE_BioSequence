# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('training_history_0.csv')
data
# Out:
#      Unnamed: 0      Loss    ValLoss  ReconstructRate  ValReconstructRate
# 0             0  2.976915   2.893277         0.865119            0.865662
# 1             1  2.889873   2.884365         0.865986            0.866339
# 2             2  2.883563   2.881879         0.866410            0.866493
# 3             3  2.881519   2.881659         0.866473            0.866387
# 4             4  2.880353   2.880069         0.866576            0.866622
# ..          ...       ...        ...              ...                 ...
# 495         495  0.033844  10.768677         0.998211            0.862827
# 496         496  0.033843  10.768695         0.998189            0.862815
# 497         497  0.033843  10.768680         0.998212            0.862820
# 498         498  0.033843  10.768675         0.998205            0.862823
# 499         499  0.033844  10.768637         0.998186            0.862824
#
# [500 rows x 5 columns]

# %%
plt.plot(data['Loss'], label = 'loss')
plt.plot(data['ValLoss'], label = 'val_loss')
plt.legend()

# %%
plt.plot(data['ReconstructRate'], label = 'reconst')
plt.plot(data['ValReconstructRate'], label = 'val_reconst')
plt.legend()
