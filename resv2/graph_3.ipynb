# %% [markdown]
# Uniref 90
# lr 1e-3, 0.93 decay
# 100k

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('training_history_3.csv')
data
# Out:
#      Unnamed: 0      Loss    ValLoss  ReconstructRate  ValReconstructRate
# 0             0  2.915600   2.871228         0.867338            0.868502
# 1             1  2.868033   2.866657         0.868543            0.868497
# 2             2  2.864435   2.862919         0.868681            0.868727
# 3             3  2.862251   2.861568         0.868743            0.868592
# 4             4  2.860082   2.862109         0.868900            0.868523
# ..          ...       ...        ...              ...                 ...
# 495         495  0.057881  11.975504         0.997190            0.862998
# 496         496  0.057881  11.975526         0.997187            0.862996
# 497         497  0.057881  11.975514         0.997184            0.862998
# 498         498  0.057881  11.975517         0.997186            0.862997
# 499         499  0.057882  11.975513         0.997188            0.862994
#
# [500 rows x 5 columns]

# %%
plt.plot(data['Loss'], label = 'loss')
plt.plot(data['ValLoss'], label = 'val_loss')
plt.legend()

# %%
plt.plot(data['ReconstructRate'], label = 'reconst')
plt.plot(data['ValReconstructRate'], label = 'val_reconst')
plt.legend()
