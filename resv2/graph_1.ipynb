# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('training_history_1.csv')
data
# Out:
#      Unnamed: 0      Loss    ValLoss  ReconstructRate  ValReconstructRate
# 0             0  3.060297   2.899667         0.864548            0.865699
# 1             1  2.897651   2.896352         0.865525            0.865997
# 2             2  2.891549   2.888878         0.865905            0.866063
# 3             3  2.887413   2.887737         0.866061            0.866295
# 4             4  2.884638   2.885020         0.866286            0.866426
# ..          ...       ...        ...              ...                 ...
# 495         495  0.034946  10.214082         0.998086            0.862713
# 496         496  0.034945  10.214087         0.998079            0.862700
# 497         497  0.034945  10.214065         0.998094            0.862701
# 498         498  0.034946  10.214067         0.998076            0.862709
# 499         499  0.034946  10.214074         0.998096            0.862701
#
# [500 rows x 5 columns]

# %%
plt.plot(data['Loss'], label = 'loss')
plt.plot(data['ValLoss'], label = 'val_loss')
plt.legend()

# %%
plt.plot(data['ReconstructRate'], label = 'reconst')
plt.plot(data['ValReconstructRate'], label = 'val_reconst')
plt.legend()
