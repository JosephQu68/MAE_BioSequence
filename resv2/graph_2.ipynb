# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('training_history_2.csv')
data
# Out:
#      Unnamed: 0      Loss   ValLoss  ReconstructRate  ValReconstructRate
# 0             0  5.944356  5.444438         0.863292            0.863103
# 1             1  5.493558  5.629663         0.863613            0.863103
# 2             2  5.447707  5.448021         0.863976            0.865228
# 3             3  5.443490  5.446185         0.863941            0.861699
# 4             4  5.442964  5.442176         0.864003            0.865228
# ..          ...       ...       ...              ...                 ...
# 495         495  2.896954  2.895830         0.866829            0.866993
# 496         496  2.896954  2.895830         0.866826            0.866993
# 497         497  2.896953  2.895830         0.866825            0.866993
# 498         498  2.896953  2.895830         0.866828            0.866993
# 499         499  2.896954  2.895830         0.866825            0.866993
#
# [500 rows x 5 columns]

# %%
plt.plot(data['Loss'], label = 'loss')
plt.plot(data['ValLoss'], label = 'val_loss')
plt.legend()

# %%
plt.plot(data['ReconstructRate'], label = 'reconst')
plt.plot(data['ValReconstructRate'], label = 'val_reconst')
plt.legend()
