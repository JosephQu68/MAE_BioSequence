# %% [markdown]
# Uniref 90
# lr 1e-3, 0.93 decay
# 100k

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('training_history_30k_bidir_discrete_masking_1e-4_small64.csv')
data
# Out:
#      Unnamed: 0      Loss    ValLoss  ReconstructRate  ValReconstructRate
# 0             0  2.944616   2.891193         0.874658            0.875182
# 1             1  2.882483   2.879080         0.875811            0.876147
# 2             2  2.874285   2.872904         0.876228            0.876688
# 3             3  2.869798   2.869662         0.876400            0.876763
# 4             4  2.866444   2.866230         0.876626            0.876786
# ..          ...       ...        ...              ...                 ...
# 495         495  0.157599  12.406520         0.994269            0.872599
# 496         496  0.109455  12.420134         0.997394            0.872681
# 497         497  0.084873  12.433442         0.998701            0.872662
# 498         498  0.073805  12.449808         0.999149            0.872702
# 499         499  0.068135  12.466571         0.999323            0.872652
#
# [500 rows x 5 columns]

# %%
plt.plot(data['Loss'], label = 'loss')
plt.plot(data['ValLoss'], label = 'val_loss')
plt.legend()

# %%
print(max((data['ValReconstructRate']-0.85)/0.15))
plt.plot((data['ReconstructRate']-0.85)/0.15, label = 'reconst')
plt.plot((data['ValReconstructRate']-0.85)/0.15, label = 'val_reconst')
plt.legend()
# Out:
# 0.18821493784586604
